# %%
from sodapy import Socrata
import pandas as pd
socket.getaddrinfo('localhost', 8080)


client = Socrata('data.cambridgema.gov'
                ,MyAppToken
                ,username='YOUR USERNAME HERE'
                 ,password='YOUR PASSWORD HERE'
                )

result = client.get('2z9k-mv9g')

print(result)
# Out:
# [{'ticket_id': '6345844', 'city': 'Cambridge', 'issue_type': 'Construction Complaint', 'ticket_status': 'open', 'issue_description': "To whom it may concern:We are residents living at Pacific Street/ Brookline St, Cambridge. For almost 2-3 months there's construction work taking place right outside our area, generating huge noise. It starts as early as 7 am every weekday. We work in the daytime, so may adjust our schedules. However, the construction work sometimes happens at 10-11 PM. This has seriously impacted our rest and sleep.Plus, at the end of each day, the construction site is covered with some thin metal boards. The street is not blocked, so all day long, whenever there's a vehicle passing by, big noise comes up.  This noise comes up once every few seconds or minutes all night long. Again this has seriously impacted our rest and sleep.We have been trying to adjust to this noisy environment for months. However, we are no longer able to do so. Your prompt attention and help on
# ...
